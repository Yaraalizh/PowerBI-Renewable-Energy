# %%
import numpy as np
import pandas as pd

# %%
WorldConsumption =pd.read_csv("World Consumption.csv")
WorldConsumption
# Out:
#     Region  Year                  Type         Value      Date
# 0    World  1965  Traditional biofuels   9162.456946  1/1/1965
# 1    World  1965            Hydropower    919.770276  1/1/1965
# 2    World  1965                 Solar      0.000000  1/1/1965
# 3    World  1965                  Wind      0.000000  1/1/1965
# 4    World  1965      Other renewables     17.985232  1/1/1965
# ..     ...   ...                   ...           ...       ...
# 260  World  2017  Traditional biofuels  10895.320490  1/1/2017
# 261  World  2017            Hydropower   4065.443127  1/1/2017
# 262  World  2017                 Solar    453.517657  1/1/2017
# 263  World  2017                  Wind   1127.989587  1/1/2017
# 264  World  2017      Other renewables    584.975827  1/1/2017
#
# [265 rows x 5 columns]

# %%
WorldConsumption.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region       265 non-null    object
#  1   Year         265 non-null    int64
#  2   Type         265 non-null    object
#  3   Value        265 non-null    float64
#  4   Date         265 non-null    object
#  5   Grand Total  54 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 12.6+ KB

# %%
duplicate_rows = WorldConsumption[WorldConsumption.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
null_values = WorldConsumption.isnull().sum()
print(null_values)
# Out:
# Region           0
# Year             0
# Type             0
# Value            0
# Date             0
# Grand Total    211
# dtype: int64

# %%
pivot = WorldConsumption.pivot(index=['Year','Region','Date'], columns='Type', values='Value')
pivot = pivot.reset_index()
print(pivot)
pivot.to_csv('Cleaned_WorldConsumption.csv', index=False)
# Out:
# Type  Year Region      Date   Hydropower  Other renewables       Solar  \
# 0     1965  World  1/1/1965   919.770276         17.985232    0.000000
# 1     1966  World  1/1/1966   986.285872         19.806007    0.000000
# 2     1967  World  1/1/1967  1009.244569         19.986571    0.000000
# 3     1968  World  1/1/1968  1059.062860         22.120045    0.000000
# 4     1969  World  1/1/1969  1122.442526         23.257964    0.000000
# 5     1970  World  1/1/1970  1174.560348         25.693196    0.000000
# 6     1971  World  1/1/1971  1221.632730         27.879168    0.000000
# 7     1972  World  1/1/1972  1276.766396         29.877101    0.000000
# 8     1973  World  1/1/1973  1292.752251         32.084924    0.000000
# 9     1974  World  1/1/1974  1419.046721         33.958814    0.000000
# 10    1975  World  1/1/1975  1440.451903         34.483679    0.000000
# 11    1976  World  1/1/1976  1435.228335         38.460956    0.000000
# ...
